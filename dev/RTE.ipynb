# %%
import pandas as pd
import numpy as np

# %%
folder="/mnt/c/Users/guera/projects/E-CUBE"
df_RTE=pd.read_csv(folder+"/data/conso-elec-gaz-annuelle-par-secteur-dactivite-agregee-iris_RTE.csv", sep=';')
df_RTE
# Out:
#     Opérateur  Année      Filière  Consommation Agriculture (MWh)  \
# 0         RTE   2017  Electricité                             0.0
# 1         RTE   2017  Electricité                             0.0
# 2         RTE   2017  Electricité                             0.0
# 3         RTE   2017  Electricité                             0.0
# 4         RTE   2017  Electricité                             0.0
# ..        ...    ...          ...                             ...
# 955       RTE   2017  Electricité                             0.0
# 956       RTE   2017  Electricité                             0.0
# 957       RTE   2017  Electricité                             0.0
# 958       RTE   2017  Electricité                             0.0
# 959       RTE   2017  Electricité                             0.0
#
#      Nombre de points Agriculture  \
# 0                               0
# 1                               0
# 2                               0
# ...

# %%
df_sum=df_RTE[['Nombre de points Agriculture','Nombre de points Industrie','Nombre de points Tertiaire']].sum()
df_sum.sum
# Out:
# <bound method Series.sum of Nombre de points Agriculture      0
# Nombre de points Industrie      630
# Nombre de points Tertiaire      642
# dtype: int64>

# %%
df_elec_RTE=df_RTE[['Code IRIS','Consommation Totale (MWh)']]
df_elec_RTE['Nombre de Points'] = df_RTE['Nombre de points Agriculture']+df_RTE['Nombre de points Industrie']+df_RTE['Nombre de points Tertiaire']
df_elec_RTE['Consommation Moyenne (MWh)'] = df_elec_RTE['Consommation Totale (MWh)']/df_elec_RTE['Nombre de Points']
df_elec_RTE
# Out:
# /home/guera/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/guera/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#      Code IRIS  Consommation Totale (MWh)  Nombre de Points  \
# 0     10100000                  504384.49                 1
# ...

# %%
df_elec_RTE.to_csv(folder+"/data/conso-elec-gaz-annuelle-par-secteur-dactivite-agregee-iris_RTE_moy.csv")
